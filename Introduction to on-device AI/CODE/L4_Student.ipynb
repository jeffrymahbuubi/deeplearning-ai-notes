# %% [markdown]
# # L4: Quantizing Models

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# - Download files from the Hub: https://huggingface.co/docs/huggingface_hub/guides/download

# %%
from huggingface_hub import snapshot_download, hf_hub_download

LOCAL_DIR = r'E:\AUNUUN JEFFRY MAHBUUBI\Programming\DEEPLEARNINGAI\Introduction to on-device AI\DATA'

# hf_hub_download(repo_id="UrbanSyn/UrbanSyn", filename="rgb/*_00*.png", repo_type="dataset", local_dir=LOCAL_DIR)
snapshot_download(repo_id="UrbanSyn/UrbanSyn", allow_patterns="rgb/*_00*.png", repo_type="dataset", local_dir=LOCAL_DIR)

# %%
from datasets import load_dataset

# Use input resolution of the network
input_shape = (1, 3, 1024, 2048)

# Load 100 RGB images of urban scenes 
# dataset = load_dataset("UrbanSyn/UrbanSyn", 
#                 split="train", 
#                 data_files="rgb/*_00*.png")
# dataset = dataset.train_test_split(1)

DATA_DIR = r'E:\AUNUUN JEFFRY MAHBUUBI\Programming\DEEPLEARNINGAI\Introduction to on-device AI\DATA'
dataset = load_dataset(path=DATA_DIR, data_files="rgb/*_00*.png", split="train")
print(dataset)

dataset = dataset.train_test_split(1)

# Hold out for testing
calibration_dataset = dataset["train"]
test_dataset = dataset["test"]
# Out:
# Resolving data files:   0%|          | 0/99 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/99 [00:00<?, ?it/s]
# Dataset({
#     features: ['image'],
#     num_rows: 99
# })

# %%
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image'],
#         num_rows: 98
#     })
#     test: Dataset({
#         features: ['image'],
#         num_rows: 1
#     })
# })

# %% [markdown]
# ## Setup calibration/inference pipleline

# %%
import torch
from torchvision import transforms

# Convert the PIL image above to Torch Tensor
preprocess = transforms.ToTensor()

# Get a sample image in the test dataset
test_sample_pil = test_dataset[0]["image"]
test_sample = preprocess(test_sample_pil).unsqueeze(0) 
print(test_sample)
# Out:
# C:\Users\LENOVO X1E\.conda\envs\HUGGINGFACE\lib\site-packages\onnxscript\converter.py:823: FutureWarning: 'onnxscript.values.Op.param_schemas' is deprecated in version 0.1 and will be removed in the future. Please use '.op_signature' instead.
#   param_schemas = callee.param_schemas()
# C:\Users\LENOVO X1E\.conda\envs\HUGGINGFACE\lib\site-packages\onnxscript\converter.py:823: FutureWarning: 'onnxscript.values.OnnxFunction.param_schemas' is deprecated in version 0.1 and will be removed in the future. Please use '.op_signature' instead.
#   param_schemas = callee.param_schemas()
# tensor([[[[0.6235, 0.6235, 0.6235,  ..., 0.4039, 0.4118, 0.4118],
#           [0.6235, 0.6235, 0.6235,  ..., 0.4706, 0.4706, 0.4667],
#           [0.6235, 0.6196, 0.6235,  ..., 0.5020, 0.4824, 0.4784],
#           ...,
#           [0.2706, 0.2706, 0.2706,  ..., 0.2745, 0.2784, 0.2824],
#           [0.2745, 0.2706, 0.2706,  ..., 0.2863, 0.2902, 0.2863],
#           [0.2784, 0.2706, 0.2745,  ..., 0.2863, 0.2902, 0.2784]],
#
#          [[0.6431, 0.6392, 0.6392,  ..., 0.3765, 0.3843, 0.3882],
#           [0.6392, 0.6392, 0.6392,  ..., 0.4314, 0.4353, 0.4353],
#           [0.6392, 0.6392, 0.6392,  ..., 0.4588, 0.4471, 0.4471],
#           ...,
#           [0.2745, 0.2745, 0.2745,  ..., 0.2824, 0.2824, 0.2863],
#           [0.2784, 0.2784, 0.2745,  ..., 0.2902, 0.2980, 0.2863],
#           [0.2824, 0.2745, 0.2784,  ..., 0.2902, 0.2941, 0.2824]],
#
#          [[0.6588, 0.6588, 0.6549,  ..., 0.3608, 0.3686, 0.3686],
#           [0.6588, 0.6588, 0.6549,  ..., 0.4157, 0.4196, 0.4196],
#           [0.6549, 0.6549, 0.6588,  ..., 0.4431, 0.4275, 0.4314],
#           ...,
#           [0.2706, 0.2706, 0.2706,  ..., 0.2745, 0.2745, 0.2824],
#           [0.2745, 0.2745, 0.2745,  ..., 0.2824, 0.2941, 0.2824],
#           [0.2784, 0.2706, 0.2745,  ..., 0.2863, 0.2863, 0.2745]]]])

# %%
import torch.nn.functional as F
import numpy as np
from PIL import Image

def postprocess(output_tensor, input_image_pil):

    # Upsample the output to the original size
    output_tensor_upsampled = F.interpolate(
        output_tensor, input_shape[2:], mode="bilinear",
    )

    # Get top predicted class and convert to numpy
    output_predictions = output_tensor_upsampled[0].argmax(0).byte().detach().numpy().astype(np.uint8)

    # Overlay over original image
    color_mask = Image.fromarray(output_predictions).convert("P")

    # Create an appropriate palette for the Cityscapes classes
    palette = [
        128, 64, 128, 244, 35, 232, 70, 70, 70, 102, 102, 156,
        190, 153, 153, 153, 153, 153, 250, 170, 30, 220, 220, 0,
        107, 142, 35, 152, 251, 152, 70, 130, 180, 220, 20, 60,
        255, 0, 0, 0, 0, 142, 0, 0, 70, 0, 60, 100, 0, 80, 100,
        0, 0, 230, 119, 11, 32]
    palette = palette + (256 * 3 - len(palette)) * [0]
    color_mask.putpalette(palette)
    out = Image.blend(input_image_pil, color_mask.convert("RGB"), 0.5)
    return out

# %% [markdown]
# ## Setup model in floating point

# %%
from qai_hub_models.models.ffnet_40s.model import FFNet40S
model = FFNet40S.from_pretrained().model.eval()

# Run sample output through the model
test_output_fp32 = model(test_sample)
test_output_fp32

postprocess(test_output_fp32, test_sample_pil)
# Out:
# Loading pretrained model state dict from C:\Users\LENOVO X1E\.qaihm\models\ffnet\v1\ffnet40S/ffnet40S_dBBB_cityscapes_state_dict_quarts.pth
# Initializing ffnnet40S_dBBB_mobile weights
# <PIL.Image.Image image mode=RGB size=2048x1024>

# %% [markdown]
# ## Prepare Quantized Model

# %% [markdown]
# - [AI Model Efficiency Toolkit (AIMET) - GitHub](https://github.com/quic/aimet)
# - [AIMET - Landing Page](https://quic.github.io/aimet-pages/index.html)

# %%
from qai_hub_models.models._shared.ffnet_quantized.model import FFNET_AIMET_CONFIG
from aimet_torch.batch_norm_fold import fold_all_batch_norms
from aimet_torch.model_preparer import prepare_model
from aimet_torch.quantsim import QuantizationSimModel

# Prepare model for 8-bit quantization
fold_all_batch_norms(model, [input_shape])
model = prepare_model(model)

# Setup quantization simulator
quant_sim = QuantizationSimModel(
    model,
    quant_scheme="tf_enhanced",
    default_param_bw=8,              # Use bitwidth 8-bit
    default_output_bw=8,
    config_file=FFNET_AIMET_CONFIG,
    dummy_input=torch.rand(input_shape),
)
# Out:
# 2025-03-05 15:12:24,136 - root - INFO - AIMET
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 from qai_hub_models.models._shared.ffnet_quantized.model import FFNET_AIMET_CONFIG
#       2 from aimet_torch.batch_norm_fold import fold_all_batch_norms
#       3 from aimet_torch.model_preparer import prepare_model
#
# File ~\.conda\envs\HUGGINGFACE\lib\site-packages\qai_hub_models\models\_shared\ffnet_quantized\model.py:9
#       5 from __future__ import annotations
#       7 # isort: off
#       8 # This verifies aimet is installed, and this must be included first.
# ----> 9 from qai_hub_models.utils.quantization_aimet import (
#      10     AIMETQuantizableMixin,
#      11     constrain_quantized_inputs_to_image_range,
#      12 )
#      14 # isort: on
#      16 import os
#
# File ~\.conda\envs\HUGGINGFACE\lib\site-packages\qai_hub_models\utils\quantization_aimet.py:14
#      11 import os
#      13 try:
# ---> 14     import aimet_torch.elementwise_ops as aimet_ops
#      15     from aimet_common.connected_graph.operation import Op as AimetOp
#      16     from aimet_common.connected_graph.product import Product as AimetProduct
#
# File ~\.conda\envs\HUGGINGFACE\lib\site-packages\aimet_torch\__init__.py:44
#       1 # -*- mode: python -*-
#       2 # =============================================================================
#       3 #  @@-COPYRIGHT-START-@@
#    (...)
#      40 # For more information about explicit namespace packages,
#      41 # see https://packaging.python.org/en/latest/guides/packaging-namespace-packages
#      42 __path__ = __import__('pkgutil').extend_path(__path__, __name__)
# ---> 44 from .quantsim import QuantizationSimModel
#      45 from . import nn
#      47 try:
#
# File ~\.conda\envs\HUGGINGFACE\lib\site-packages\aimet_torch\quantsim.py:60
#      56     _warn_replaced_in_v2(__name__,
#      57                          v2_new_api=_v2_quantsim.__name__,
#      58                          v1_legacy_api=_v1_quantsim.__name__)
#      59 else:
# ---> 60     from .v2.quantsim import (
#      61         QuantizationSimModel,
#      62         QuantParams,
#      63         ExportableQuantModule,
#      64         save_checkpoint,
#      65         load_checkpoint,
#      66         check_accumulator_overflow,
#      67         load_encodings_to_sim,
#      68         compute_encodings_for_sims,
#      69     )
#      72 __all__ = [
#      73     'QuantizationSimModel',
#      74     'QuantParams',
#    (...)
#      80     'compute_encodings_for_sims',
#      81 ]
#      83 undefined = set(__all__) - set(globals())
#
# File ~\.conda\envs\HUGGINGFACE\lib\site-packages\aimet_torch\v2\__init__.py:38
#       1 # -*- mode: python -*-
#       2 # =============================================================================
#       3 #  @@-COPYRIGHT-START-@@
#    (...)
#      35 #  @@-COPYRIGHT-END-@@
#      36 # =============================================================================
#      37 """ aimet_torch.v2 subpackage """
# ---> 38 from . import experimental
#      39 from . import nn
#      40 from . import quantization
#
# File ~\.conda\envs\HUGGINGFACE\lib\site-packages\aimet_torch\v2\experimental\__init__.py:41
#      39 from . import onnx
#      40 from . import lora
# ---> 41 from .quantsim_utils import *
#
# File ~\.conda\envs\HUGGINGFACE\lib\site-packages\aimet_torch\v2\experimental\quantsim_utils.py:45
#      43 from aimet_common.connected_graph.product import Product
#      44 from aimet_torch.meta.connectedgraph import Op
# ---> 45 from aimet_torch.v2.nn import BaseQuantizationMixin, custom
#      46 from aimet_torch.v2.quantization.affine.quantizer import AffineQuantizerBase
#      47 from aimet_torch.v2.quantsim import QuantizationSimModel
#
# File ~\.conda\envs\HUGGINGFACE\lib\site-packages\aimet_torch\v2\nn\__init__.py:42
#      40 import torch
#      41 from aimet_torch.v2.deepspeed_utils import _register_zero3_forward_hooks
# ---> 42 from .fake_quant import *  # pylint: disable=import-error
#      43 from .true_quant import *  # pylint: disable=import-error
#      44 from .base import * # pylint: disable=import-error
#
# File ~\.conda\envs\HUGGINGFACE\lib\site-packages\aimet_torch\v2\nn\fake_quant\__init__.py:48
#      46 import torch
#      47 from packaging import version
# ---> 48 from .. import true_quant as _nn
#      50 FakeQuantizationMixin = _nn.QuantizationMixin
#      51 FakeQuantizedAdaptiveMaxPool1d = _nn.QuantizedAdaptiveMaxPool1d
#
# File ~\.conda\envs\HUGGINGFACE\lib\site-packages\aimet_torch\v2\nn\true_quant.py:66
#      54 from torch.overrides import BaseTorchFunctionMode, get_overridable_functions
#      55 from torch._VF import ( # pylint: disable=no-name-in-module
#      56     gru as _gru,
#      57     gru_cell as _gru_cell,
#    (...)
#      63     rnn_tanh_cell as _rnn_tanh_cell,
#      64 )
# ---> 66 from aimet_torch.v2.quantization.base import QuantizerBase
#      67 from aimet_torch.v2.quantization.tensor import QuantizedTensorBase
#      68 from aimet_torch.v2.utils import patch_attr, _ContextManager, allow_recompute
#
# File ~\.conda\envs\HUGGINGFACE\lib\site-packages\aimet_torch\v2\quantization\__init__.py:40
#      38 from .tensor import *
#      39 from . import base
# ---> 40 from . import affine
#      41 from . import float
#
# File ~\.conda\envs\HUGGINGFACE\lib\site-packages\aimet_torch\v2\quantization\affine\__init__.py:40
#       1 # -*- mode: python -*-
#       2 # =============================================================================
#       3 #  @@-COPYRIGHT-START-@@
#    (...)
#      37
#      38 # pylint: disable=all
# ---> 40 from .encoding import *
#      41 from .quantizer import *
#      42 from .backends import *
#
# File ~\.conda\envs\HUGGINGFACE\lib\site-packages\aimet_torch\v2\quantization\affine\encoding.py:48
#      46 from aimet_torch.v2.utils import docstring
#      47 from aimet_torch.v2.quantization.base import EncodingBase
# ---> 48 from aimet_torch.v2.quantization.affine.backends import quantize, dequantize, _derive_qmin_qmax
#      49 from ._utils import _GridMixin, _register_signature # pylint: disable=import-error
#      52 __all__ = ["AffineEncoding", "VectorEncoding", "GroupedBlockEncoding"]
#
# File ~\.conda\envs\HUGGINGFACE\lib\site-packages\aimet_torch\v2\quantization\affine\backends\__init__.py:43
#      41 from typing import overload, Union, Tuple, Optional
#      42 import torch
# ---> 43 from .utils import *
#      46 @overload
#      47 def quantize(tensor: torch.Tensor, scale: torch.Tensor, offset: torch.Tensor,
#      48              bitwidth: Union[int, float], signed: bool = False,
#      49              block_size: Optional[Tuple[int, ...]] = None):
#      50     ...
#
# File ~\.conda\envs\HUGGINGFACE\lib\site-packages\aimet_torch\v2\quantization\affine\backends\utils.py:39
#       1 # -*- mode: python -*-
#       2 # =============================================================================
#       3 #  @@-COPYRIGHT-START-@@
#    (...)
#      36 # =============================================================================
#      37 # pylint: disable=all
#      38 import torch
# ---> 39 from aimet_torch.v2.quantization.affine.backends import torch_builtins
#      41 from typing import List, Optional, Protocol
#      42 from aimet_torch.v2.utils import _ContextManager
#
# File ~\.conda\envs\HUGGINGFACE\lib\site-packages\aimet_torch\v2\quantization\affine\backends\torch_builtins.py:214
#     208     return DequantizeFunc.apply(tensor,
#     209                                 scale.to(internal_dtype),
#     210                                 offset.to(internal_dtype)).to(output_dtype).view(orig_tensor_shape)
#     213 # pylint: disable=abstract-method
# --> 214 class QuantizeFunc(torch.autograd.Function):
#     215     """
#     216     Custom gradient function for quantization
#     217     """
#     218     # pylint: disable=arguments-differ, protected-access
#
# File ~\.conda\envs\HUGGINGFACE\lib\site-packages\aimet_torch\v2\quantization\affine\backends\torch_builtins.py:242, in QuantizeFunc()
#     237     ctx.save_for_backward(tensor if scale.requires_grad else None,
#     238                           scale if tensor.requires_grad or scale.requires_grad else None,
#     239                           mask)
#     240     return x_round.clamp_(qmin, qmax)
# --> 242 _compiled_forward_impl = staticmethod(_compile(_forward_impl.__func__))
#     244 # pylint: disable=arguments-differ
#     245 @staticmethod
#     246 def backward(ctx, grad):
#
# File ~\.conda\envs\HUGGINGFACE\lib\site-packages\torch\__init__.py:1723, in compile(model, fullgraph, dynamic, backend, mode, options, disable)
#    1720 else:
#    1721     backend = _TorchCompileWrapper(backend, mode, options, dynamic)
# -> 1723 return torch._dynamo.optimize(backend=backend, nopython=fullgraph, dynamic=dynamic, disable=disable)(model)
#
# File ~\.conda\envs\HUGGINGFACE\lib\site-packages\torch\_dynamo\eval_frame.py:583, in optimize(backend, nopython, guard_export_fn, guard_fail_fn, disable, dynamic)
#     548 def optimize(
#     549     backend="inductor",
#     550     *,
#    (...)
#     555     dynamic=None,
#     556 ):
#     557     """
#     558     The main entrypoint of TorchDynamo.  Do graph capture and call
#     559     backend() to optimize extracted graphs.
#    (...)
#     581             ...
#     582     """
# --> 583     check_if_dynamo_supported()
#     584     # Note: The hooks object could be global instead of passed around, *however* that would make
#     585     # for a confusing API usage and plumbing story wherein we nest multiple .optimize calls.
#     586     # There is some prior art around this, w/r/t nesting backend calls are enforced to be the same
#     587     # compiler, however, this feels onerous for callback and hooks, and it feels better to give our users an
#     588     # easier to understand UX at the cost of a little more plumbing on our end.
#     589     hooks = Hooks(guard_export_fn=guard_export_fn, guard_fail_fn=guard_fail_fn)
#
# File ~\.conda\envs\HUGGINGFACE\lib\site-packages\torch\_dynamo\eval_frame.py:535, in check_if_dynamo_supported()
#     533 def check_if_dynamo_supported():
#     534     if sys.platform == "win32":
# --> 535         raise RuntimeError("Windows not yet supported for torch.compile")
#     536     if sys.version_info >= (3, 12):
#     537         raise RuntimeError("Python 3.12+ not yet supported for torch.compile")
#
# RuntimeError: Windows not yet supported for torch.compile

# %% [markdown]
# ## Perform post training quantization

# %%
size = 5  # Must be < 100

def pass_calibration_data(sim_model: torch.nn.Module, args):
    (dataset,) = args
    with torch.no_grad():
        for sample in dataset.select(range(size)):
            pil_image = sample["image"]
            input_batch = preprocess(pil_image).unsqueeze(0)

            # Feed sample through for calibration
            sim_model(input_batch)

# Run Post-Training Quantization (PTQ)
quant_sim.compute_encodings(pass_calibration_data, [calibration_dataset])

# %%
test_output_int8 = quant_sim.model(test_sample)
postprocess(test_output_int8, test_sample_pil)

# %% [markdown]
# ## Run Quantized model on-device

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access Utils File and Helper Functions:</b> To access the files for this notebook, 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %%
import qai_hub
import qai_hub_models

from utils import get_ai_hub_api_token
ai_hub_api_token = get_ai_hub_api_token()

# !qai-hub configure --api_token $ai_hub_api_token

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note:</b> To spread the load across various devices, we are selecting a random device. Feel free to change it to any other device you prefer.</p>

# %%
devices = [
    "Samsung Galaxy S22 Ultra 5G",
    "Samsung Galaxy S22 5G",
    "Samsung Galaxy S22+ 5G",
    "Samsung Galaxy Tab S8",
    "Xiaomi 12",
    "Xiaomi 12 Pro",
    "Samsung Galaxy S22 5G",
    "Samsung Galaxy S23",
    "Samsung Galaxy S23+",
    "Samsung Galaxy S23 Ultra",
    "Samsung Galaxy S24",
    "Samsung Galaxy S24 Ultra",
    "Samsung Galaxy S24+",
]

import random
selected_device = random.choice(devices)
print(selected_device)

# %%
# %run -m qai_hub_models.models.ffnet_40s_quantized.export -- --device "$selected_device"
